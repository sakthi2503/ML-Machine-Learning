# %%
A)	How will you achieve this in AI?
•	Predict which employees are likely to resign with their recent activities
•	We have to note their historical emp details like age, exp, job role, Performance rating, Overtime hrs, Attendance record, Extra training attended, Work Satisfaction.
•	We have to create one simple model with an output(YES-1/NO-0) based on our inputs

B)	Find out the 3 -Stage of Problem Identification?
•	ML – Machine Learning
•	We have inputs and outputs so falls under supervised 
•	Classification – Output based Inputs.

C)	Name the project – Smart Employee Resignation Prediction System

D)	Dummy DataSet:

Age	Job Role	Performance rating	Overtime hrs	Attendance Record	Extra Training	Work Satisfaction Level	Resign Prediction
35	TL	              7             	0	           Medium	1	                                                                         poor	      Yes
30	SE	9	12	Good	5	                                                                         Good	      No
38	Manager	8	5	Excellent	4	                                                                 Good         No
